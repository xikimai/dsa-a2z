# %% [markdown]
# # Challenge 02 Prime Check**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/challenge_02_prime_check.py)---Challenge 02: Prime Check==============================Chapter 3: Decisions and LoopsPROBLEM-------Given an integer n, determine whether it is a prime number.A prime number is greater than 1 and has no divisors other than 1and itself. Return True if n is prime, False otherwise.INPUT FORMAT------------A single line containing an integer n.OUTPUT FORMAT-------------Print True or False.CONSTRAINTS------------10^9 <= n <= 10^9EXAMPLES--------Input:  2Output: TrueInput:  17Output: TrueInput:  4Output: FalseInput:  1Output: FalseInput:  -5Output: FalseINSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> bool:    """Return True if n is prime, False otherwise."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(2) is Trueassert solve(3) is Trueassert solve(4) is Falseassert solve(1) is Falseassert solve(0) is Falseassert solve(17) is Trueassert solve(25) is Falseassert solve(97) is Trueassert solve(-5) is Falseprint("All tests passed!")
