# %% [markdown]
# # Warmup 01 Even Odd**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/warmup_01_even_odd.py)---Warmup 01: Even or Odd==============================Chapter 3: Decisions and LoopsPROBLEM-------Given an integer n, determine whether it is even or odd.INPUT FORMAT------------A single line containing an integer n.OUTPUT FORMAT-------------Print "Even" if n is even, "Odd" if n is odd.CONSTRAINTS------------10^9 <= n <= 10^9EXAMPLES--------Input:  4Output: EvenInput:  7Output: OddInput:  0Output: EvenINSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> str:    """Return 'Even' if n is even, 'Odd' if n is odd."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(4) == "Even"assert solve(7) == "Odd"assert solve(0) == "Even"assert solve(-3) == "Odd"assert solve(1) == "Odd"print("All tests passed!")
