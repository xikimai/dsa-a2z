# %% [markdown]
# # Practice 02 Digit Count**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/practice_02_digit_count.py)---Practice 02: Digit Count==============================Chapter 3: Decisions and LoopsPROBLEM-------Given an integer n, count the number of digits it has.For n = 0, the answer is 1.Handle negative numbers by counting the digits of the absolute value.INPUT FORMAT------------A single line containing an integer n.OUTPUT FORMAT-------------Print the number of digits in n.CONSTRAINTS------------10^9 <= n <= 10^9EXAMPLES--------Input:  12345Output: 5Input:  0Output: 1Input:  9Output: 1Input:  -42Output: 2Input:  1000000Output: 7INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> int:    """Return the number of digits in n."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(12345) == 5assert solve(0) == 1assert solve(9) == 1assert solve(-42) == 2assert solve(1000000) == 7print("All tests passed!")
