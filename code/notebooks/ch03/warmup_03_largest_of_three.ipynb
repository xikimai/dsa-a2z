# %% [markdown]
# # Warmup 03 Largest Of Three**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/warmup_03_largest_of_three.py)---Warmup 03: Largest of Three==============================Chapter 3: Decisions and LoopsPROBLEM-------Given three integers a, b, and c, return the largest of the three.INPUT FORMAT------------A single line containing three space-separated integers a, b, c.OUTPUT FORMAT-------------Print the largest of the three integers.CONSTRAINTS------------10^9 <= a, b, c <= 10^9EXAMPLES--------Input:  1 2 3Output: 3Input:  3 2 1Output: 3Input:  5 5 5Output: 5Input:  -1 -2 -3Output: -1INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(a: int, b: int, c: int) -> int:    """Return the largest of three integers."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(1, 2, 3) == 3assert solve(3, 2, 1) == 3assert solve(5, 5, 5) == 5assert solve(-1, -2, -3) == -1assert solve(10, 5, 10) == 10print("All tests passed!")
