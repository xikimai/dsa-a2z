# %% [markdown]
# # Warmup 05 Sum 1 To N**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/warmup_05_sum_1_to_n.py)---Warmup 05: Sum 1 to N==============================Chapter 3: Decisions and LoopsPROBLEM-------Given a non-negative integer n, return the sum 1 + 2 + ... + n using aloop. Do NOT use the formula n*(n+1)/2 — the point is to practice loops!INPUT FORMAT------------A single line containing a non-negative integer n.OUTPUT FORMAT-------------Print the sum of all integers from 1 to n.CONSTRAINTS-----------0 <= n <= 10^6EXAMPLES--------Input:  5Output: 15Input:  1Output: 1Input:  10Output: 55Input:  0Output: 0INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> int:    """Return the sum 1 + 2 + ... + n using a loop."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(5) == 15assert solve(1) == 1assert solve(10) == 55assert solve(100) == 5050assert solve(0) == 0print("All tests passed!")
