# %% [markdown]
# # Warmup 06 Multiplication Table**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/warmup_06_multiplication_table.py)---Warmup 06: Multiplication Table==============================Chapter 3: Decisions and LoopsPROBLEM-------Given an integer n, return its multiplication table as a list of stringsin the format "i x n = result" for i from 1 to 10.INPUT FORMAT------------A single line containing an integer n.OUTPUT FORMAT-------------Print 10 lines, each showing "i x n = result".CONSTRAINTS-----------1 <= n <= 100EXAMPLES--------Input:  7Output:1 x 7 = 72 x 7 = 143 x 7 = 214 x 7 = 285 x 7 = 356 x 7 = 427 x 7 = 498 x 7 = 569 x 7 = 6310 x 7 = 70INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> list[str]:    """Return n's multiplication table as a list of strings."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert result == [assert result[0] == "1 x 1 = 1"assert result[-1] == "10 x 1 = 10"assert result[0] == "1 x 5 = 5"assert result[-1] == "10 x 5 = 50"assert len(solve(3)) == 10assert len(solve(99)) == 10print("All tests passed!")
