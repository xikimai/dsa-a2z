# %% [markdown]
# # Practice 03 Reverse Number**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/practice_03_reverse_number.py)---Practice 03: Reverse Number==============================Chapter 3: Decisions and LoopsPROBLEM-------Given an integer n, reverse its digits. For negative numbers, reverse thedigits and keep the negative sign. Leading zeros in the reversed resultshould be dropped (e.g., 1200 reversed is 21, not 0021).INPUT FORMAT------------A single line containing an integer n.OUTPUT FORMAT-------------Print the reversed integer.CONSTRAINTS------------10^9 <= n <= 10^9EXAMPLES--------Input:  1234Output: 4321Input:  1200Output: 21Input:  5Output: 5Input:  -123Output: -321Input:  0Output: 0INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> int:    """Return the integer with its digits reversed."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(1234) == 4321assert solve(1200) == 21assert solve(5) == 5assert solve(-123) == -321assert solve(0) == 0assert solve(100) == 1print("All tests passed!")
