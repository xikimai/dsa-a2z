# %% [markdown]
# # Warmup 02 Absolute Value**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/warmup_02_absolute_value.py)---Warmup 02: Absolute Value==============================Chapter 3: Decisions and LoopsPROBLEM-------Given an integer n, return its absolute value WITHOUT using the built-inabs() function. Use an if/else to handle positive and negative numbers.INPUT FORMAT------------A single line containing an integer n.OUTPUT FORMAT-------------Print the absolute value of n.CONSTRAINTS------------10^9 <= n <= 10^9EXAMPLES--------Input:  5Output: 5Input:  -5Output: 5Input:  0Output: 0INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> int:    """Return the absolute value of n without using abs()."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(5) == 5assert solve(-5) == 5assert solve(0) == 0assert solve(-100) == 100assert solve(1) == 1print("All tests passed!")
