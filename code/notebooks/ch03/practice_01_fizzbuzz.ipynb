# %% [markdown]
# # Practice 01 Fizzbuzz**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/practice_01_fizzbuzz.py)---Practice 01: FizzBuzz==============================Chapter 3: Decisions and LoopsPROBLEM-------Given a positive integer n, return the FizzBuzz sequence from 1 to n.For each number:  - If divisible by both 3 and 5, use "FizzBuzz"  - If divisible by 3 only, use "Fizz"  - If divisible by 5 only, use "Buzz"  - Otherwise, use the number as a stringINPUT FORMAT------------A single line containing a positive integer n.OUTPUT FORMAT-------------Print each element of the FizzBuzz sequence on its own line.CONSTRAINTS-----------1 <= n <= 1000EXAMPLES--------Input:  5Output:12Fizz4BuzzInput:  15Output:12Fizz4BuzzFizz78FizzBuzz11Fizz1314FizzBuzzINSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> list[str]:    """Return the FizzBuzz sequence from 1 to n."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(15) == expectedassert solve(1) == ["1"]assert result[-1] == "Buzz"assert solve(3) == ["1", "2", "Fizz"]print("All tests passed!")
