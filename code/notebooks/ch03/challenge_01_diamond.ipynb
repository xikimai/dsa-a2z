# %% [markdown]
# # Challenge 01 Diamond**Chapter 03** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch03/practice/challenge_01_diamond.py)---Challenge 01: Diamond Pattern==============================Chapter 3: Decisions and LoopsPROBLEM-------Given a positive integer n, return a diamond pattern of stars. The tophalf (including the middle row) has n rows. The total height is 2n - 1.Each row has leading spaces followed by an odd number of stars.No trailing spaces on any row. Rows separated by newlines.No trailing newline.INPUT FORMAT------------A single line containing a positive integer n.OUTPUT FORMAT-------------Print the diamond pattern.CONSTRAINTS-----------1 <= n <= 50EXAMPLES--------Input:  3Output:  * ******** ***  *Input:  1Output:*Input:  2Output: **** *INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> str:    """Return a diamond pattern of stars with n rows in the top half."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(1) == "*"assert solve(2) == " *\n***\n *"assert solve(3) == "  *\n ***\n*****\n ***\n  *"assert len(lines) == 7assert lines[3] == "*******"print("All tests passed!")
