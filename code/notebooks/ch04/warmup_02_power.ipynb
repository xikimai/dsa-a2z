# %% [markdown]
# # Warmup 02 Power**Chapter 04** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch04/practice/warmup_02_power.py)---Warmup 2: Power==============================Chapter 4: FunctionsPROBLEM-------Compute base raised to the power of exponent using a loop.Do NOT use the built-in pow() or the ** operator.INPUT FORMAT------------Two integers on separate lines: base, then exponent.OUTPUT FORMAT-------------A single integer: the result of base^exponent.CONSTRAINTS------------ exponent >= 0- base can be any integer (including 0 and negatives)EXAMPLES--------Input:  2, 10Output: 1024Input:  5, 0Output: 1Input:  0, 5Output: 0INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(base: int, exponent: int) -> int:    """Compute base^exponent using a loop (no built-in pow or **)."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(2, 10) == 1024assert solve(5, 3) == 125assert solve(7, 0) == 1assert solve(9, 1) == 9assert solve(0, 5) == 0assert solve(1, 100) == 1assert solve(-2, 4) == 16assert solve(-2, 3) == -8print("All tests passed!")
