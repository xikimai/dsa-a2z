# %% [markdown]
# # Warmup 04 Repeat String**Chapter 04** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch04/practice/warmup_04_repeat_string.py)---Warmup 4: Repeat String==============================Chapter 4: FunctionsPROBLEM-------Return a string repeated n times, separated by spaces.If n is 0, return an empty string.INPUT FORMAT------------A string on the first line, then an integer n on the second line.OUTPUT FORMAT-------------The string repeated n times with spaces between them.CONSTRAINTS------------ n >= 0- s can be any stringEXAMPLES--------Input:  ha, 3Output: ha ha haInput:  yo, 5Output: yo yo yo yo yoInput:  x, 0Output: (empty string)INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(s: str, n: int = 3) -> str:    """Return s repeated n times separated by spaces."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve("ha") == "ha ha ha"assert solve("yo", 5) == "yo yo yo yo yo"assert solve("!", 1) == "!"assert solve("x", 0) == ""assert solve("hi there", 2) == "hi there hi there"assert solve("a", 4) == "a a a a"print("All tests passed!")
