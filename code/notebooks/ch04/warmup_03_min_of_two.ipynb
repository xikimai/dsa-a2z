# %% [markdown]
# # Warmup 03 Min Of Two**Chapter 04** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch04/practice/warmup_03_min_of_two.py)---Warmup 3: Min of Three (Using a Helper)==============================Chapter 4: FunctionsPROBLEM-------Find the minimum of three integers. You MUST define a helper functioncalled min_of_two(a, b) that returns the smaller of two values, thenuse it inside solve() to find the minimum of three.INPUT FORMAT------------Three integers on separate lines.OUTPUT FORMAT-------------A single integer: the smallest of the three.CONSTRAINTS------------ All values are integers (can be negative)EXAMPLES--------Input:  5, 2, 8Output: 2Input:  -1, -5, 3Output: -5Input:  4, 4, 4Output: 4INSTRUCTIONS------------Replace the `pass` in both min_of_two() and solve() with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def min_of_two(a: int, b: int) -> int:    """Return the smaller of a and b."""    pass  # TODO: Replace this with your solutiondef solve(a: int, b: int, c: int) -> int:    """Return the minimum of a, b, and c using min_of_two."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(5, 3, 1) == 1assert solve(1, 5, 3) == 1assert solve(5, 1, 3) == 1assert solve(4, 4, 4) == 4assert solve(2, 2, 5) == 2assert solve(-1, -5, 3) == -5assert solve(-10, -20, -5) == -20assert solve(0, 5, -3) == -3print("All tests passed!")
