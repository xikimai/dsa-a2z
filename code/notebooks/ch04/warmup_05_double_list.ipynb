# %% [markdown]
# # Warmup 05 Double List**Chapter 04** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch04/practice/warmup_05_double_list.py)---Warmup 5: Double List==============================Chapter 4: FunctionsPROBLEM-------Double every element in the list IN PLACE and return the same list.This means you should modify the original list, not create a new one.INPUT FORMAT------------A line of space-separated integers.OUTPUT FORMAT-------------The same integers, each doubled, space-separated.CONSTRAINTS------------ List can be empty- Elements can be negative or zeroEXAMPLES--------Input:  1 2 3Output: 2 4 6Input:  -1 0 5Output: -2 0 10Input:  (empty)Output: (empty)INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(nums: list[int]) -> list[int]:    """Double every element in nums in place and return the list."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve([1, 2, 3]) == [2, 4, 6]assert solve([]) == []assert solve([5]) == [10]assert solve([-1, -3]) == [-2, -6]assert solve([0, 0, 0]) == [0, 0, 0]assert solve([-1, 0, 5]) == [-2, 0, 10]assert result is original  # Same object, not a copyassert original == [2, 4, 6]print("All tests passed!")
