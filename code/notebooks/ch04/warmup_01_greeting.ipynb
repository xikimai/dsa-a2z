# %% [markdown]
# # Warmup 01 Greeting**Chapter 04** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch04/practice/warmup_01_greeting.py)---Warmup 1: Greeting==============================Chapter 4: FunctionsPROBLEM-------Write a function that takes a person's name and returns a greeting string.INPUT FORMAT------------A single string: the person's name.OUTPUT FORMAT-------------A string in the format "Hello, {name}!"CONSTRAINTS------------ name can be any string, including an empty stringEXAMPLES--------Input:  AliceOutput: Hello, Alice!Input:  (empty string)Output: Hello, !INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(name: str) -> str:    """Return a greeting string for the given name."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve("Alice") == "Hello, Alice!"assert solve("Bob") == "Hello, Bob!"assert solve("") == "Hello, !"assert solve("Mary Jane") == "Hello, Mary Jane!"assert solve("X") == "Hello, X!"assert solve("Agent007") == "Hello, Agent007!"print("All tests passed!")
