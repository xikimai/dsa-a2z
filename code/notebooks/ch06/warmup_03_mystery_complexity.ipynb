# %% [markdown]
# # Warmup 03 Mystery Complexity**Chapter 06** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch06/practice/warmup_03_mystery_complexity.py)---Warmup 3: Mystery Complexity==============================Chapter 6: How Fast Is Your Code?PROBLEM-------You ran a mystery function on several input sizes and recorded how manyoperations it performed.  Given parallel lists of n_values and counts,figure out the Big-O complexity class.Classification rules (using consecutive pairs where n roughly doubles):  - All counts are the same                  -> "O(1)"  - Count increases by ~1 when n doubles     -> "O(log n)"  - Count doubles when n doubles             -> "O(n)"  - Count quadruples when n doubles          -> "O(n^2)"INPUT FORMAT------------Two lines:  Line 1: space-separated n_values (integers)  Line 2: space-separated counts (integers)OUTPUT FORMAT-------------One of: "O(1)", "O(log n)", "O(n)", "O(n^2)"CONSTRAINTS------------ At least 2 data points- n_values are in increasing order- Consecutive n_values roughly double (ratio close to 2)EXAMPLES--------Input:  1 10 100 1000  5 5 5 5Output: O(1)Input:  100 200 400 800  100 200 400 800Output: O(n)INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n_values: list[int], counts: list[int]) -> str:    """Classify the growth rate from observed (n, count) data points."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve([1, 10, 100, 1000], [5, 5, 5, 5]) == "O(1)"assert solve([1, 2, 4, 8, 16], [0, 1, 2, 3, 4]) == "O(log n)"assert solve([100, 200, 400, 800], [100, 200, 400, 800]) == "O(n)"assert solve([10, 20, 40, 80], [100, 400, 1600, 6400]) == "O(n^2)"assert solve([1000, 2000, 4000], [1000, 2000, 4000]) == "O(n)"print("All tests passed!")
