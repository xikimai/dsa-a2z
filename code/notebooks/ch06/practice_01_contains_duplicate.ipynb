# %% [markdown]
# # Practice 01 Contains Duplicate**Chapter 06** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch06/practice/practice_01_contains_duplicate.py)---Practice 1: Contains Duplicate==============================Chapter 6: How Fast Is Your Code?PROBLEM-------Given a list of integers, return True if any value appears at leasttwice in the list.  Return False if every element is distinct.Use a set for O(n) time complexity.INPUT FORMAT------------A single line of space-separated integers (may be empty).OUTPUT FORMAT-------------True or FalseCONSTRAINTS------------ 0 <= len(nums) <= 10^5- -10^9 <= nums[i] <= 10^9EXAMPLES--------Input:  1 2 3 1Output: TrueInput:  1 2 3 4Output: FalseInput:  (empty)Output: FalseINSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(nums: list[int]) -> bool:    """Return True if any value appears at least twice."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve([1, 2, 3, 1]) is Trueassert solve([1, 2, 3, 4]) is Falseassert solve([]) is Falseassert solve([1]) is Falseassert solve([1, 1]) is Trueprint("All tests passed!")
