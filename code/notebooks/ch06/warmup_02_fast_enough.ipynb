# %% [markdown]
# # Warmup 02 Fast Enough**Chapter 06** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch06/practice/warmup_02_fast_enough.py)---Warmup 2: Is It Fast Enough?==============================Chapter 6: How Fast Is Your Code?PROBLEM-------Given an input size n and a complexity string, determine whether analgorithm with that complexity would finish in time — i.e., whetherthe number of operations is strictly less than 10^8 (100 million).Complexity strings and their operation counts:  "1"       -> 1  "log_n"   -> log2(n)  "n"       -> n  "n_log_n" -> n * log2(n)  "n^2"     -> n * n  "n^3"     -> n * n * n  "2^n"     -> 2^n  (if n > 30, return False immediately)INPUT FORMAT------------A single line with two values separated by a space: n (integer) andcomplexity (string).OUTPUT FORMAT-------------True or FalseCONSTRAINTS------------ 1 <= n <= 10^9- complexity is one of the seven valid stringsEXAMPLES--------Input:  1000 n^2Output: TrueInput:  100000 n^2Output: FalseINSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
import mathdef solve(n: int, complexity: str) -> bool:    """Return True if the algorithm finishes within 10^8 operations."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(1000, "n^2") is Trueassert solve(100000, "n^2") is Falseassert solve(10000, "n^2") is Falseassert solve(9999, "n^2") is Trueassert solve(30, "2^n") is Falseassert solve(20, "2^n") is Trueassert solve(1000000, "n") is Trueassert solve(1000000, "n_log_n") is Trueassert solve(100000000, "1") is Trueprint("All tests passed!")
