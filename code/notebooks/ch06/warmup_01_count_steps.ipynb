# %% [markdown]
# # Warmup 01 Count Steps**Chapter 06** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch06/practice/warmup_01_count_steps.py)---Warmup 1: Count the Steps==============================Chapter 6: How Fast Is Your Code?PROBLEM-------Given a code_id string and an integer n, return the exact number ofoperations that the corresponding code pattern would perform.The code patterns are:  "single_loop"    -> n              (one loop from 1 to n)  "double_loop"    -> n * n          (two nested loops, each 1 to n)  "half_loop"      -> n // 2         (loop that skips every other)  "dependent_loop" -> n*(n+1) // 2   (inner loop depends on outer)  "log_loop"       -> floor(log2(n)) (halving loop), 0 if n < 1INPUT FORMAT------------Two lines:  Line 1: a code_id string (one of the five above)  Line 2: an integer nOUTPUT FORMAT-------------A single integer: the operation count.CONSTRAINTS------------ 0 <= n <= 10^9- code_id is always one of the five valid stringsEXAMPLES--------Input:  single_loop  100Output: 100Input:  log_loop  16Output: 4INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
import mathdef solve(code_id: str, n: int) -> int:    """Return the exact operation count for the given code pattern and n."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve("single_loop", 100) == 100assert solve("double_loop", 10) == 100assert solve("half_loop", 100) == 50assert solve("half_loop", 7) == 3assert solve("dependent_loop", 4) == 10assert solve("log_loop", 16) == 4assert solve("log_loop", 1) == 0assert solve("log_loop", 1024) == 10print("All tests passed!")
