# %% [markdown]
# # Warmup 05 Last Digit**Chapter 02** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch02/practice/warmup_05_last_digit.py)---Warmup 05: Last Digit==============================Chapter 2: Your First ProgramsPROBLEM-------Given an integer n, return its last digit. If n is negative, return thelast digit of its absolute value.INPUT FORMAT------------A single line containing an integer n.OUTPUT FORMAT-------------Print a single integer — the last digit of n.CONSTRAINTS------------10^9 <= n <= 10^9EXAMPLES--------Input:  12345Output: 5Input:  100Output: 0Input:  -789Output: 9Input:  7Output: 7INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> int:    """Return the last digit of n (always non-negative)."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(12345) == 5assert solve(100) == 0assert solve(-789) == 9assert solve(7) == 7assert solve(0) == 0assert solve(-10) == 0print("All tests passed!")
