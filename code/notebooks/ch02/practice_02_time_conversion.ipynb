# %% [markdown]
# # Practice 02 Time Conversion**Chapter 02** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch02/practice/practice_02_time_conversion.py)---Practice 02: Time Conversion==============================Chapter 2: Your First ProgramsPROBLEM-------Given a total number of seconds, convert it to hours, minutes, and seconds.For example, 3661 seconds = 1 hour, 1 minute, and 1 second.INPUT FORMAT------------A single line containing a non-negative integer — total seconds.OUTPUT FORMAT-------------Print three space-separated integers: hours, minutes, seconds.CONSTRAINTS-----------0 <= total_seconds <= 86400EXAMPLES--------Input:  3661Output: 1 1 1Input:  0Output: 0 0 0Input:  86399Output: 23 59 59Input:  45Output: 0 0 45Input:  3600Output: 1 0 0INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(total_seconds: int) -> tuple[int, int, int]:    """Return a tuple (hours, minutes, seconds) from the given total seconds."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(3661) == (1, 1, 1)assert solve(0) == (0, 0, 0)assert solve(86399) == (23, 59, 59)assert solve(45) == (0, 0, 45)assert solve(3600) == (1, 0, 0)assert solve(60) == (0, 1, 0)assert solve(9000) == (2, 30, 0)print("All tests passed!")
