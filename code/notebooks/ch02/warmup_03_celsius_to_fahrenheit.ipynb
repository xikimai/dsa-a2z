# %% [markdown]
# # Warmup 03 Celsius To Fahrenheit**Chapter 02** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch02/practice/warmup_03_celsius_to_fahrenheit.py)---Warmup 03: Celsius to Fahrenheit==============================Chapter 2: Your First ProgramsPROBLEM-------Given a temperature in Celsius, convert it to Fahrenheit using the formula:    F = C * 9/5 + 32INPUT FORMAT------------A single line containing a float — the temperature in Celsius.OUTPUT FORMAT-------------Print the temperature in Fahrenheit as a float.CONSTRAINTS------------273.15 <= celsius <= 10^6EXAMPLES--------Input:  0.0Output: 32.0Input:  100.0Output: 212.0Input:  -40.0Output: -40.0Input:  37.0Output: 98.6INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(celsius: float) -> float:    """Convert Celsius to Fahrenheit and return the result."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(0.0) == pytest.approx(32.0, abs=1e-4)assert solve(100.0) == pytest.approx(212.0, abs=1e-4)assert solve(-40.0) == pytest.approx(-40.0, abs=1e-4)assert solve(37.0) == pytest.approx(98.6, abs=1e-4)assert solve(20.0) == pytest.approx(68.0, abs=1e-4)print("All tests passed!")
