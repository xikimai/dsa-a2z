# %% [markdown]
# # Challenge 02 Quadratic**Chapter 02** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch02/practice/challenge_02_quadratic.py)---Challenge 02: Quadratic Discriminant==============================Chapter 2: Your First ProgramsPROBLEM-------Given coefficients a, b, and c of a quadratic equation ax^2 + bx + c = 0,compute the discriminant and determine the number of real roots.The discriminant is:    disc = b^2 - 4acNumber of real roots:    - 2 roots if disc > 0    - 1 root  if disc == 0    - 0 roots if disc < 0INPUT FORMAT------------A single line containing three space-separated floats: a, b, c.OUTPUT FORMAT-------------Print the discriminant (as a float) and the number of roots (as an integer),separated by a space.CONSTRAINTS------------10^3 <= a, b, c <= 10^3a != 0EXAMPLES--------Input:  1 -3 2Output: 1.0 2Input:  1 2 1Output: 0.0 1Input:  1 1 1Output: -3.0 0INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(a: float, b: float, c: float) -> tuple[float, int]:    """Return a tuple (discriminant, num_roots) for the quadratic ax^2 + bx + c = 0."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert disc == pytest.approx(1.0, abs=1e-4)assert num_roots == 2assert disc == pytest.approx(0.0, abs=1e-4)assert num_roots == 1assert disc == pytest.approx(-3.0, abs=1e-4)assert num_roots == 0assert disc == pytest.approx(96.0, abs=1e-4)assert num_roots == 2assert disc == pytest.approx(0.0, abs=1e-4)assert num_roots == 1print("All tests passed!")
