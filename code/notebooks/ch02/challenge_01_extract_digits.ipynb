# %% [markdown]
# # Challenge 01 Extract Digits**Chapter 02** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch02/practice/challenge_01_extract_digits.py)---Challenge 01: Extract Digits==============================Chapter 2: Your First ProgramsPROBLEM-------Given a 3-digit integer n, extract its hundreds digit, tens digit, andones digit. Use integer division and modulo — no string tricks allowed!INPUT FORMAT------------A single line containing a 3-digit integer n.OUTPUT FORMAT-------------Print three space-separated integers: hundreds, tens, ones.CONSTRAINTS-----------100 <= n <= 999EXAMPLES--------Input:  123Output: 1 2 3Input:  907Output: 9 0 7Input:  100Output: 1 0 0Input:  999Output: 9 9 9INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(n: int) -> tuple[int, int, int]:    """Return a tuple (hundreds, tens, ones) for a 3-digit number n."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve(123) == (1, 2, 3)assert solve(907) == (9, 0, 7)assert solve(100) == (1, 0, 0)assert solve(999) == (9, 9, 9)assert solve(456) == (4, 5, 6)assert solve(500) == (5, 0, 0)print("All tests passed!")
