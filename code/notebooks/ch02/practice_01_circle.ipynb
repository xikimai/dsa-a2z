# %% [markdown]
# # Practice 01 Circle**Chapter 02** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch02/practice/practice_01_circle.py)---Practice 01: Circle Properties==============================Chapter 2: Your First ProgramsPROBLEM-------Given the radius of a circle, compute its area and circumference.Formulas:    area = pi * r^2    circumference = 2 * pi * rUse math.pi for the value of pi.INPUT FORMAT------------A single line containing a float — the radius.OUTPUT FORMAT-------------Print two floats on separate lines: the area and the circumference.CONSTRAINTS-----------0 < radius <= 10^4EXAMPLES--------Input:  1.0Output: 3.141592653589793        6.283185307179586Input:  5.0Output: 78.53981633974483        31.41592653589793INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
import mathdef solve(radius: float) -> tuple[float, float]:    """Return a tuple (area, circumference) for a circle with the given radius."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert area == pytest.approx(math.pi, abs=1e-4)assert circ == pytest.approx(2 * math.pi, abs=1e-4)assert area == pytest.approx(78.5398, abs=1e-4)assert circ == pytest.approx(31.4159, abs=1e-4)assert area == pytest.approx(314.1593, abs=1e-4)assert circ == pytest.approx(62.8319, abs=1e-4)assert area == pytest.approx(0.7854, abs=1e-4)assert circ == pytest.approx(3.1416, abs=1e-4)assert area == pytest.approx(31415.9265, abs=1e-2)assert circ == pytest.approx(628.3185, abs=1e-4)print("All tests passed!")
