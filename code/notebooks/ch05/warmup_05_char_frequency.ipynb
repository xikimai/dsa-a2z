# %% [markdown]
# # Warmup 05 Char Frequency**Chapter 05** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch05/practice/warmup_05_char_frequency.py)---Warmup 5: Character Frequency==============================Chapter 5: CollectionsPROBLEM-------Given a string, return a dictionary mapping each character to itsfrequency (how many times it appears).INPUT FORMAT------------A single line of text.OUTPUT FORMAT-------------Key:count pairs, one per line, sorted by key.CONSTRAINTS------------ The string can be empty- All characters count (including spaces, punctuation)EXAMPLES--------Input:  aabOutput:a:2b:1INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(s: str) -> dict[str, int]:    """Return a dict mapping each character to its frequency."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve("aab") == {"a": 2, "b": 1}assert solve("") == {}assert solve("abc") == {"a": 1, "b": 1, "c": 1}assert solve("aaa") == {"a": 3}assert result == {"a": 1, " ": 1, "b": 1}print("All tests passed!")
