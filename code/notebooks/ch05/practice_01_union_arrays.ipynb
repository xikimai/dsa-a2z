# %% [markdown]
# # Practice 01 Union Arrays**Chapter 05** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch05/practice/practice_01_union_arrays.py)---Practice 1: Union of Two Arrays================================Chapter 5: CollectionsPROBLEM-------Given two lists of integers, return their sorted union — a sorted listcontaining all unique elements that appear in either list.INPUT FORMAT------------Two lines, each containing space-separated integers.OUTPUT FORMAT-------------A single line of space-separated integers (the sorted union).CONSTRAINTS------------ Lists can be empty- Lists may contain duplicates- Elements can be negativeEXAMPLES--------Input:1 2 33 4 5Output: 1 2 3 4 5Input:1 1 22 3 3Output: 1 2 3INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(a: list[int], b: list[int]) -> list[int]:    """Return the sorted union of two lists (unique elements from both)."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve([1, 2, 3], [3, 4, 5]) == [1, 2, 3, 4, 5]assert solve([1, 1, 2], [2, 3, 3]) == [1, 2, 3]assert solve([], [1, 2]) == [1, 2]assert solve([1], [1]) == [1]assert solve([1, 3, 5], [2, 4, 6]) == [1, 2, 3, 4, 5, 6]print("All tests passed!")
