# %% [markdown]
# # Warmup 03 Count Vowels**Chapter 05** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch05/practice/warmup_03_count_vowels.py)---Warmup 3: Count Vowels==============================Chapter 5: CollectionsPROBLEM-------Count the number of vowels (a, e, i, o, u) in a string.The count should be case-insensitive (both 'A' and 'a' count).INPUT FORMAT------------A single line of text.OUTPUT FORMAT-------------A single integer: the count of vowels.CONSTRAINTS------------ The string can be empty- The string can contain any characters (letters, digits, punctuation)EXAMPLES--------Input:  Hello WorldOutput: 3Input:  aeiouOutput: 5Input:  xyzOutput: 0INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(s: str) -> int:    """Return the count of vowels in the string (case-insensitive)."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve("Hello World") == 3assert solve("aeiou") == 5assert solve("xyz") == 0assert solve("") == 0assert solve("AEIOU") == 5assert solve("rhythm") == 0print("All tests passed!")
