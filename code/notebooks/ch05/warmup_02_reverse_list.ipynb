# %% [markdown]
# # Warmup 02 Reverse List**Chapter 05** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch05/practice/warmup_02_reverse_list.py)---Warmup 2: Reverse List==============================Chapter 5: CollectionsPROBLEM-------Reverse a list of integers in place without using the built-in reverse()method or slicing tricks. Return the reversed list.INPUT FORMAT------------A single line of space-separated integers.OUTPUT FORMAT-------------The reversed list as space-separated integers.CONSTRAINTS------------ The list can be empty or have one element- Elements can be negativeEXAMPLES--------Input:  1 2 3 4 5Output: 5 4 3 2 1Input:  1Output: 1INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(nums: list[int]) -> list[int]:    """Reverse the list in place and return it."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve([1, 2, 3, 4, 5]) == [5, 4, 3, 2, 1]assert solve([1]) == [1]assert solve([]) == []assert solve([1, 2]) == [2, 1]assert solve([5, 4, 3, 2, 1]) == [1, 2, 3, 4, 5]print("All tests passed!")
