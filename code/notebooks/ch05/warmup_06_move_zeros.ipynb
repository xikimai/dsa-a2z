# %% [markdown]
# # Warmup 06 Move Zeros**Chapter 05** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch05/practice/warmup_06_move_zeros.py)---Warmup 6: Move Zeros==============================Chapter 5: CollectionsPROBLEM-------Move all zeros in a list to the end while maintaining the relativeorder of the non-zero elements. Do this in place.INPUT FORMAT------------A single line of space-separated integers.OUTPUT FORMAT-------------The modified list as space-separated integers.CONSTRAINTS------------ The list can be empty- Elements can be negative (only 0 is moved)EXAMPLES--------Input:  0 1 0 3 12Output: 1 3 12 0 0Input:  0 0 1Output: 1 0 0Input:  1 2 3Output: 1 2 3INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(nums: list[int]) -> list[int]:    """Move all zeros to the end in place and return the list."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve([0, 1, 0, 3, 12]) == [1, 3, 12, 0, 0]assert solve([0, 0, 1]) == [1, 0, 0]assert solve([1, 2, 3]) == [1, 2, 3]assert solve([0]) == [0]assert solve([]) == []print("All tests passed!")
