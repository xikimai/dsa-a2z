# %% [markdown]
# # Challenge 02 Group Anagrams**Chapter 05** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch05/practice/challenge_02_group_anagrams.py)---Challenge 2: Group Anagrams==============================Chapter 5: CollectionsPROBLEM-------Given a list of strings, group the anagrams together. An anagram is aword formed by rearranging the letters of another word.Return the groups as a list of lists. Each inner group should be sortedalphabetically, and the outer list should be sorted by the first elementof each group.INPUT FORMAT------------A single line of space-separated strings.OUTPUT FORMAT-------------Groups on separate lines, each group as space-separated strings.CONSTRAINTS------------ 1 <= len(strs) <= 10^4- 0 <= len(strs[i]) <= 100- strs[i] contains only lowercase English lettersEXAMPLES--------Input:  eat tea tan ate nat batOutput:ate eat teabatnat tanInput:  aOutput:aINSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(strs: list[str]) -> list[list[str]]:    """Group anagrams together. Inner sorted, outer sorted by first element."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert result == [["ate", "eat", "tea"], ["bat"], ["nat", "tan"]]assert solve([""]) == [[""]]assert solve(["a"]) == [["a"]]assert result == [["abc"], ["def"], ["ghi"]]assert result == [["abc", "bca", "cab"]]print("All tests passed!")
