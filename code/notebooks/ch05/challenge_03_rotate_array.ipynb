# %% [markdown]
# # Challenge 03 Rotate Array**Chapter 05** | [View in GitHub](https://github.com/xikimai/dsa-a2z/blob/main/code/python/ch05/practice/challenge_03_rotate_array.py)---Challenge 3: Rotate Array==============================Chapter 5: CollectionsPROBLEM-------Given a list of integers and a non-negative integer k, rotate the listto the right by k steps.For example, [1,2,3,4,5,6,7] rotated by k=3 becomes [5,6,7,1,2,3,4].Handle cases where k is larger than the length of the list.INPUT FORMAT------------First line: space-separated integers (the list).Second line: a single integer k.OUTPUT FORMAT-------------The rotated list as space-separated integers.CONSTRAINTS------------ The list can be empty or have one element- 0 <= k <= 10^5- k can be larger than len(nums)EXAMPLES--------Input:1 2 3 4 5 6 73Output: 5 6 7 1 2 3 4Input:1 23Output: 2 1Input:-1 -100 3 992Output: 3 99 -1 -100INSTRUCTIONS------------Replace the `pass` in the solve() function with your solution.The main block at the bottom handles input/output — don't change it.

# %% [markdown]
# ## Your SolutionImplement the function(s) below. Replace `pass` with your code.

# %%
def solve(nums: list[int], k: int) -> list[int]:    """Rotate the list to the right by k steps and return it."""    pass  # TODO: Replace this with your solution

# %% [markdown]
# ## Test Your SolutionRun the cell below to check your work. All asserts should pass silently.

# %%
# Run these tests to check your solutionassert solve([1, 2, 3, 4, 5, 6, 7], 3) == [5, 6, 7, 1, 2, 3, 4]assert solve([1, 2], 3) == [2, 1]assert solve([1], 5) == [1]assert solve([-1, -100, 3, 99], 2) == [3, 99, -1, -100]assert solve([1, 2, 3], 0) == [1, 2, 3]print("All tests passed!")
